# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv('sonar_dataset.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df = df.rename(columns={60: 'Target'})
df.sample(5)
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 11   0.0123  0.0309  0.0169  0.0313  0.0358  0.0102  0.0182  0.0579  0.1122
# 52   0.0087  0.0046  0.0081  0.0230  0.0586  0.0682  0.0993  0.0717  0.0576
# 177  0.0201  0.0165  0.0344  0.0330  0.0397  0.0443  0.0684  0.0903  0.1739
# 189  0.0158  0.0239  0.0150  0.0494  0.0988  0.1425  0.1463  0.1219  0.1697
# 106  0.0331  0.0423  0.0474  0.0818  0.0835  0.0756  0.0374  0.0961  0.0548
#
#           9  ...      51      52      53      54      55      56      57  \
# 11   0.0835  ...  0.0133  0.0265  0.0224  0.0074  0.0118  0.0026  0.0092
# 52   0.0818  ...  0.0052  0.0038  0.0079  0.0114  0.0050  0.0030  0.0064
# 177  0.2571  ...  0.0054  0.0057  0.0137  0.0109  0.0035  0.0056  0.0105
# 189  0.1923  ...  0.0121  0.0108  0.0057  0.0028  0.0079  0.0034  0.0046
# 106  0.0193  ...  0.0078  0.0174  0.0176  0.0038  0.0129  0.0066  0.0044
#
#          58      59  Target
# 11   0.0009  0.0044       R
# ...

# %%
df.Target = df.Target.astype('str')

# %%
df['Target'] = df.Target.map({'R': 0, 'M': 1})
df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  Target
# 0  0.0090  0.0032       0
# 1  0.0052  0.0044       0
# ...

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :60], df.Target, test_size=0.25, random_state=1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((156, 60), (52, 60), (156,), (52,))

# %% [markdown]
# ## Without Dropout Regularization

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(60, activation='relu', input_shape=(60,)))
model.add(keras.layers.Dense(30, activation='relu'))
model.add(keras.layers.Dense(15, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 3ms/step - loss: 0.6905 - accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6795 - accuracy: 0.6346
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6543 - accuracy: 0.6474
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6242 - accuracy: 0.6987
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5977 - accuracy: 0.7115
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5573 - accuracy: 0.7692
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.7821
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5031 - accuracy: 0.7372
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4334 - accuracy: 0.8077
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2034 - accuracy: 0.7692
# [1.2033898830413818, 0.7692307829856873]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74        25
#            1       0.74      0.85      0.79        27
#
#     accuracy                           0.77        52
#    macro avg       0.78      0.77      0.77        52
# weighted avg       0.77      0.77      0.77        52

# %% [markdown]
# ## With Dropout Regularization

# %%
modeld = keras.Sequential()
modeld.add(keras.layers.Dense(60, activation='relu', input_shape=(60,)))
keras.layers.Dropout(0.3)
modeld.add(keras.layers.Dense(30, activation='relu'))
keras.layers.Dropout(0.3)
modeld.add(keras.layers.Dense(15, activation='relu'))
keras.layers.Dropout(0.3)
modeld.add(keras.layers.Dense(1, activation='sigmoid'))

modeld.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
modeld.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_44 (Dense)             (None, 60)                3660
# _________________________________________________________________
# dense_45 (Dense)             (None, 30)                1830
# _________________________________________________________________
# dense_46 (Dense)             (None, 15)                465
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 16
# ...
# Total params: 5,971
# Trainable params: 5,971
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 3s 5ms/step - loss: 0.6917 - accuracy: 0.5385
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6627 - accuracy: 0.5577
# Epoch 3/100
# ...

# %%
modeld.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9803 - accuracy: 0.7692
# [0.980272650718689, 0.7692307829856873]

# %%
y_pred = modeld.predict(X_test)
y_pred = np.round(y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74        25
#            1       0.74      0.85      0.79        27
#
#     accuracy                           0.77        52
#    macro avg       0.78      0.77      0.77        52
# weighted avg       0.77      0.77      0.77        52

# %% [markdown]
# ### Conclusion:
# Here, there is no much difference between the two models (With or Without Dropout Regularization). But, usually we use dropout regularization to resolve the issue of overfitting so that the model can be generalized better and with a better performance and accuracy.

# %%
# !pip install tensorflow_hub
